# %%
import json
import pandas as pd

json_data = r"C:\Users\IMS\Desktop\Hwangsihoon\WebCam\participant_data.json"

with open(json_data, 'r') as f:
    data = json.load(f)

# user_name 초기화를 위한 빈 리스트 생성
records = []

# 각 user_name에 대해 meta 정보와 dot_info 정보 추출 및 데이터프레임 생성
for user_name, user_data in data.items():
    meta_info = user_data["meta"]
    dot_info = user_data["dot_info"]
    for n_key, n_value in dot_info.items():
        for m_key, m_value in n_value.items():
            # 각 dot_info 항목에 meta 정보 및 user_name 추가, n, m_key : 파일명 -> User_n_m
            combined_data = {**meta_info, **m_value, "user_name": user_name, "n_key": n_key, "m_key": m_key}
            records.append(combined_data)

df = pd.DataFrame(records)

# 왼쪽, 오른쪽 눈 df화
df_right = df[['user_name', 'file_name_right', 'right_landmarks', 'label']]
df_left = df[['user_name', 'file_name_left', 'left_landmarks', 'label']]

# %%
import os
import glob
from keras.preprocessing.image import load_img, img_to_array

import numpy as np

folder_path = r"C:\Users\IMS\Desktop\Hwangsihoon\WebCam\img"

files = glob.glob(os.path.join(folder_path, '*.jpg'))

# right파일, left파일 각각 분리
right_images = [file for file in files if 'right' in os.path.basename(file).lower()]
left_images = [file for file in files if 'left' in os.path.basename(file).lower()]


def load_and_preprocess_image(image_path, target_size=(128, 128)):
    image = load_img(image_path, target_size=target_size)
    image_array = img_to_array(image)
    image_array /= 255.0
    return image_array


# First & Sceond Inpput
right_images = [load_and_preprocess_image(img_path) for img_path in right_images]
left_images = [load_and_preprocess_image(img_path) for img_path in left_images]

# Labels
right_labels = np.array(df_right['label'].tolist())
left_labels = np.array(df_left['label'].tolist())

labels = right_labels


print(labels)
# Out:
# [[0.22424955 0.28144491]
#  [0.22424955 0.28144491]
#  [0.22424955 0.28144491]
#  ...
#  [0.33093688 0.87473578]
#  [0.33093688 0.87473578]
#  [0.33093688 0.87473578]]

# %%
# Third Input
def expand_landmarks(landmarks):
    if len(landmarks) == 2:
        return pd.Series({
            'x1': landmarks[0][0],
            'y1': landmarks[0][1],
            'x2': landmarks[1][0],
            'y2': landmarks[1][1]
        })



# LandMark
right_landmark = df_right['right_landmarks']
left_landmark = df_left['left_landmarks']

right_landmarks_expanded = df_right['right_landmarks'].apply(expand_landmarks)
left_landmarks_expanded = df_left['left_landmarks'].apply(expand_landmarks)

expanded_landmarks_combined = pd.concat([right_landmarks_expanded.add_suffix('_right'), left_landmarks_expanded.add_suffix('_left')], axis=1)
landmark = np.array(expanded_landmarks_combined)
landmark
# Out:
# array([[83, 65, 46, ..., 64, 46, 65],
#        [82, 65, 46, ..., 65, 46, 66],
#        [83, 65, 46, ..., 65, 46, 66],
#        ...,
#        [84, 64, 44, ..., 63, 44, 63],
#        [84, 64, 44, ..., 64, 44, 64],
#        [84, 64, 44, ..., 64, 44, 64]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

right_images_train, right_images_test, left_images_train, left_images_test, labels_train, labels_test, landmark_train, landmark_test = train_test_split(
    right_images, left_images, labels, landmark, test_size=0.2, shuffle=True, random_state=42
)

# %%
import tensorflow as tf
from keras import layers, Model, Input

def mish(x):
    return x * (tf.math.tanh(tf.math.softplus(x)))

x1 = right_images  # 이미지
x2 = left_images
x3 = landmark

y1 = labels  # 레이블
y2 = labels

# input1 모델
input1 = Input(shape=(128, 128, 3))
x1 = layers.Conv2D(16, kernel_size=(7, 7), activation=mish, padding='same', strides=(2, 2))(input1)
x1 = layers.BatchNormalization()(x1)
x1 = layers.MaxPooling2D(pool_size=(2, 2))(x1)

x1 = layers.Conv2D(16, kernel_size=(5, 5), activation=mish, padding='same')(x1)
x1 = layers.BatchNormalization()(x1)
x1 = layers.MaxPooling2D(pool_size=(2, 2))(x1)

x1 = layers.Conv2D(32, kernel_size=(5, 5), activation=mish, padding='same')(x1)
x1 = layers.BatchNormalization()(x1)
x1 = layers.MaxPooling2D(pool_size=(2, 2))(x1)

x1 = layers.Conv2D(64, kernel_size=(3, 3), activation=mish, padding='same')(x1)
x1 = layers.BatchNormalization()(x1)
x1 = layers.MaxPooling2D(pool_size=(2, 2))(x1)

x1 = layers.Conv2D(64, kernel_size=(3, 3), activation=mish, padding='same')(x1)
x1 = layers.BatchNormalization()(x1)
x1 = layers.MaxPooling2D(pool_size=(2, 2))(x1)

x1 = layers.Flatten()(x1)  # Flatten 레이어

# input2 모델
input2 = Input(shape=(128, 128, 3))
x2 = layers.Conv2D(16, kernel_size=(7, 7), activation=mish, padding='same', strides=(2, 2))(input2)
x2 = layers.BatchNormalization()(x2)
x2 = layers.MaxPooling2D(pool_size=(2, 2))(x2)

x2 = layers.Conv2D(16, kernel_size=(5, 5), activation=mish, padding='same')(x2)
x2 = layers.BatchNormalization()(x2)
x2 = layers.MaxPooling2D(pool_size=(2, 2))(x2)

x2 = layers.Conv2D(32, kernel_size=(5, 5), activation=mish, padding='same')(x2)
x2 = layers.BatchNormalization()(x2)
x2 = layers.MaxPooling2D(pool_size=(2, 2))(x2)

x2 = layers.Conv2D(32, kernel_size=(3, 3), activation=mish, padding='same')(x2)
x2 = layers.BatchNormalization()(x2)
x2 = layers.MaxPooling2D(pool_size=(2, 2))(x2)

x2 = layers.Conv2D(64, kernel_size=(3, 3), activation=mish, padding='same')(x2)
x2 = layers.BatchNormalization()(x2)
x2 = layers.MaxPooling2D(pool_size=(2, 2))(x2)

x2 = layers.Flatten()(x2)  # Flatten 레이어

# input3 모델
input3 = Input(shape=(8,))
x3 = layers.Dense(128, activation=mish)(input3)
# x3 = layers.Dense(16, activation=mish)(x3)
# x3 = layers.Dense(16, activation=mish)(x3)

# 직렬 Concatenate
combined = layers.Concatenate()([x1, x2, x3])

# Fully Connected 층
fc_output = layers.Dense(8, activation=mish)(combined)
fc_output = layers.BatchNormalization()(fc_output)
final_output = layers.Dense(2, activation=None)(fc_output)

model = Model(inputs=[input1, input2, input3], outputs=final_output)

model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)    │ (None, 128, 128, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_7 (InputLayer)    │ (None, 128, 128, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_20 (Conv2D)            │ (None, 64, 64, 16)        │           2,368 │ input_layer_6[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_25 (Conv2D)            │ (None, 64, 64, 16)        │           2,368 │ input_layer_7[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_22        │ (None, 64, 64, 16)        │              64 │ conv2d_20[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_27        │ (None, 64, 64, 16)        │              64 │ conv2d_25[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_20              │ (None, 32, 32, 16)        │               0 │ batch_normalization_22[0]… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_25              │ (None, 32, 32, 16)        │               0 │ batch_normalization_27[0]… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_21 (Conv2D)            │ (None, 32, 32, 16)        │           6,416 │ max_pooling2d_20[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_26 (Conv2D)            │ (None, 32, 32, 16)        │           6,416 │ max_pooling2d_25[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_23        │ (None, 32, 32, 16)        │              64 │ conv2d_21[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_28        │ (None, 32, 32, 16)        │              64 │ conv2d_26[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_21              │ (None, 16, 16, 16)        │               0 │ batch_normalization_23[0]… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_26              │ (None, 16, 16, 16)        │               0 │ batch_normalization_28[0]… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_22 (Conv2D)            │ (None, 16, 16, 32)        │          12,832 │ max_pooling2d_21[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_27 (Conv2D)            │ (None, 16, 16, 32)        │          12,832 │ max_pooling2d_26[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_24        │ (None, 16, 16, 32)        │             128 │ conv2d_22[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_29        │ (None, 16, 16, 32)        │             128 │ conv2d_27[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_22              │ (None, 8, 8, 32)          │               0 │ batch_normalization_24[0]… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_27              │ (None, 8, 8, 32)          │               0 │ batch_normalization_29[0]… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_23 (Conv2D)            │ (None, 8, 8, 64)          │          18,496 │ max_pooling2d_22[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_28 (Conv2D)            │ (None, 8, 8, 32)          │           9,248 │ max_pooling2d_27[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_25        │ (None, 8, 8, 64)          │             256 │ conv2d_23[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_30        │ (None, 8, 8, 32)          │             128 │ conv2d_28[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_23              │ (None, 4, 4, 64)          │               0 │ batch_normalization_25[0]… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_28              │ (None, 4, 4, 32)          │               0 │ batch_normalization_30[0]… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_24 (Conv2D)            │ (None, 4, 4, 64)          │          36,928 │ max_pooling2d_23[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_29 (Conv2D)            │ (None, 4, 4, 64)          │          18,496 │ max_pooling2d_28[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_26        │ (None, 4, 4, 64)          │             256 │ conv2d_24[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_31        │ (None, 4, 4, 64)          │             256 │ conv2d_29[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_24              │ (None, 2, 2, 64)          │               0 │ batch_normalization_26[0]… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_29              │ (None, 2, 2, 64)          │               0 │ batch_normalization_31[0]… │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_8 (InputLayer)    │ (None, 8)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_4 (Flatten)           │ (None, 256)               │               0 │ max_pooling2d_24[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_5 (Flatten)           │ (None, 256)               │               0 │ max_pooling2d_29[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_9 (Dense)               │ (None, 128)               │           1,152 │ input_layer_8[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 640)               │               0 │ flatten_4[0][0],           │
# │                               │                           │                 │ flatten_5[0][0],           │
# │                               │                           │                 │ dense_9[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_10 (Dense)              │ (None, 8)                 │           5,128 │ concatenate_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_32        │ (None, 8)                 │              32 │ dense_10[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_11 (Dense)              │ (None, 2)                 │              18 │ batch_normalization_32[0]… │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 134,138 (523.98 KB)
#  Trainable params: 133,418 (521.16 KB)
#  Non-trainable params: 720 (2.81 KB)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_squared_log_error
import tensorflow as tf
from sklearn.metrics import accuracy_score
import numpy as np

# 유클리드 거리 계산
def euclidean_distance(y_true, y_pred):
    return np.sqrt(np.mean(np.square(y_true - y_pred), axis=-1))


right_images_train = np.array(right_images_train)
left_images_train = np.array(left_images_train)
landmark_train = np.array(landmark_train)
labels_train = np.array(labels_train)

right_images_test = np.array(right_images_test)
left_images_test = np.array(left_images_test)
landmark_test = np.array(landmark_test)
labels_test = np.array(labels_test)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.016)

# 모델 컴파일
model.compile(optimizer=optimizer, loss='mean_squared_logarithmic_error', metrics=[tf.keras.metrics.MeanSquaredError()])

# 모델 학습
history = model.fit(
    [right_images_train, left_images_train, landmark_train],  # 입력 데이터 리스트
    labels_train,                       # 레이블
    epochs=40,                                # 에포크 수
    batch_size=8,                          # 배치 사이즈
    validation_data=([right_images_test, left_images_test, landmark_test], labels_test),  # 검증 데이터와 레이블
    verbose=2                                
)

# 모델 평가
loss, mse_metric = model.evaluate([right_images_test, left_images_test, landmark_test], labels_test, verbose=0)
print(f'Test Loss (MSLE): {loss}')
print(f'Test MSE (metric): {mse_metric}')

# 예측
predictions = model.predict([right_images_test, left_images_test, landmark_test])

# 평가 지표 계산
mse = mean_squared_error(labels_test, predictions)
mae = mean_absolute_error(labels_test, predictions)
r2 = r2_score(labels_test, predictions)
euclidean_distances = euclidean_distance(labels_test, predictions)

# 결과 출력
print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')
print(f'R² Score: {r2}')
print(f'Average Euclidean Distance: {np.mean(euclidean_distances)}')

# 오차 계산
errors = labels_test - predictions

# 예측 값, 실제 값 및 오차 출력 (예시로 첫 5개 데이터만 출력)
for i in range(5):  # 예시로 첫 5개 데이터만 출력
    print(f'Actual Value:\n{labels_test[i]}')
    print(f'Predicted Value:\n{predictions[i]}')
    print(f'Error:\n{errors[i]}\n')
# Out:
# Epoch 1/40
# 3200/3200 - 361s - 113ms/step - loss: 0.0407 - mean_squared_error: 0.0924 - val_loss: 0.0395 - val_mean_squared_error: 0.0851
# Epoch 2/40
# 3200/3200 - 351s - 110ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0400 - val_mean_squared_error: 0.0871
# Epoch 3/40
# 3200/3200 - 344s - 107ms/step - loss: 0.0395 - mean_squared_error: 0.0848 - val_loss: 0.0395 - val_mean_squared_error: 0.0841
# Epoch 4/40
# 3200/3200 - 346s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0846 - val_loss: 0.0396 - val_mean_squared_error: 0.0852
# Epoch 5/40
# 3200/3200 - 349s - 109ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0394 - val_mean_squared_error: 0.0849
# Epoch 6/40
# 3200/3200 - 348s - 109ms/step - loss: 0.0393 - mean_squared_error: 0.0846 - val_loss: 0.0394 - val_mean_squared_error: 0.0847
# Epoch 7/40
# 3200/3200 - 350s - 109ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0396 - val_mean_squared_error: 0.0858
# Epoch 8/40
# 3200/3200 - 345s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0395 - val_mean_squared_error: 0.0844
# Epoch 9/40
# 3200/3200 - 345s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0846 - val_loss: 0.0398 - val_mean_squared_error: 0.0865
# Epoch 10/40
# 3200/3200 - 345s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0396 - val_mean_squared_error: 0.0842
# Epoch 11/40
# 3200/3200 - 345s - 108ms/step - loss: 0.0393 - mean_squared_error: 0.0846 - val_loss: 0.0398 - val_mean_squared_error: 0.0866
# Epoch 12/40
# 3200/3200 - 345s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0848 - val_loss: 0.0398 - val_mean_squared_error: 0.0840
# Epoch 13/40
# 3200/3200 - 347s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0846 - val_loss: 0.0398 - val_mean_squared_error: 0.0840
# Epoch 14/40
# 3200/3200 - 345s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0396 - val_mean_squared_error: 0.0843
# Epoch 15/40
# 3200/3200 - 344s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0395 - val_mean_squared_error: 0.0854
# Epoch 16/40
# 3200/3200 - 345s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0410 - val_mean_squared_error: 0.0875
# Epoch 17/40
# 3200/3200 - 343s - 107ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0394 - val_mean_squared_error: 0.0849
# Epoch 18/40
# 3200/3200 - 349s - 109ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0398 - val_mean_squared_error: 0.0863
# Epoch 19/40
# 3200/3200 - 348s - 109ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0399 - val_mean_squared_error: 0.0873
# Epoch 20/40
# 3200/3200 - 346s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0846 - val_loss: 0.0396 - val_mean_squared_error: 0.0841
# Epoch 21/40
# 3200/3200 - 346s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0405 - val_mean_squared_error: 0.0844
# Epoch 22/40
# 3200/3200 - 348s - 109ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0397 - val_mean_squared_error: 0.0862
# Epoch 23/40
# 3200/3200 - 345s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0396 - val_mean_squared_error: 0.0852
# Epoch 24/40
# 3200/3200 - 346s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0846 - val_loss: 0.0397 - val_mean_squared_error: 0.0868
# Epoch 25/40
# 3200/3200 - 348s - 109ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0404 - val_mean_squared_error: 0.0845
# Epoch 26/40
# 3200/3200 - 347s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0846 - val_loss: 0.0402 - val_mean_squared_error: 0.0886
# Epoch 27/40
# 3200/3200 - 344s - 108ms/step - loss: 0.0393 - mean_squared_error: 0.0845 - val_loss: 0.0396 - val_mean_squared_error: 0.0857
# Epoch 28/40
# 3200/3200 - 345s - 108ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0396 - val_mean_squared_error: 0.0851
# Epoch 29/40
# 3200/3200 - 340s - 106ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0405 - val_mean_squared_error: 0.0869
# Epoch 30/40
# 3200/3200 - 342s - 107ms/step - loss: 0.0393 - mean_squared_error: 0.0845 - val_loss: 0.0395 - val_mean_squared_error: 0.0853
# Epoch 31/40
# 3200/3200 - 342s - 107ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0397 - val_mean_squared_error: 0.0840
# Epoch 32/40
# 3200/3200 - 341s - 106ms/step - loss: 0.0395 - mean_squared_error: 0.0849 - val_loss: 0.0394 - val_mean_squared_error: 0.0852
# Epoch 33/40
# 3200/3200 - 344s - 107ms/step - loss: 0.0394 - mean_squared_error: 0.0846 - val_loss: 0.0394 - val_mean_squared_error: 0.0848
# Epoch 34/40
# 3200/3200 - 342s - 107ms/step - loss: 0.0394 - mean_squared_error: 0.0846 - val_loss: 0.0398 - val_mean_squared_error: 0.0872
# Epoch 35/40
# 3200/3200 - 341s - 107ms/step - loss: 0.0394 - mean_squared_error: 0.0846 - val_loss: 0.0395 - val_mean_squared_error: 0.0855
# Epoch 36/40
# 3200/3200 - 343s - 107ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0395 - val_mean_squared_error: 0.0856
# Epoch 37/40
# 3200/3200 - 343s - 107ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0395 - val_mean_squared_error: 0.0850
# Epoch 38/40
# 3200/3200 - 344s - 107ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0397 - val_mean_squared_error: 0.0867
# Epoch 39/40
# 3200/3200 - 342s - 107ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0395 - val_mean_squared_error: 0.0845
# Epoch 40/40
# 3200/3200 - 344s - 107ms/step - loss: 0.0394 - mean_squared_error: 0.0847 - val_loss: 0.0396 - val_mean_squared_error: 0.0863
# Test Loss (MSLE): 0.0395895317196846
# Test MSE (metric): 0.08625174313783646
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 74ms/step
# Mean Squared Error: 0.08625176031867923
# Mean Absolute Error: 0.25360578247575916
# R² Score: -0.027591600200852273
# Average Euclidean Distance: 0.27489095462194796
# Actual Value:
# [0.65139938 0.26187915]
# Predicted Value:
# [0.45747173 0.44640616]
# Error:
# [ 0.19392765 -0.184527  ]
#
# Actual Value:
# [0.13814909 0.25099608]
# Predicted Value:
# [0.45747173 0.44640616]
# Error:
# [-0.31932264 -0.19541008]
#
# Actual Value:
# [0.91598632 0.68996009]
# Predicted Value:
# [0.45747173 0.44640616]
# Error:
# [0.45851459 0.24355393]
#
# Actual Value:
# [0.57106538 0.0558103 ]
# Predicted Value:
# [0.45747173 0.44640616]
# Error:
# [ 0.11359366 -0.39059586]
#
# Actual Value:
# [0.33262968 0.38720694]
# Predicted Value:
# [0.45747173 0.44640616]
# Error:
# [-0.12484204 -0.05919922]
