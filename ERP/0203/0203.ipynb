# %%
import numpy as np
import matplotlib.pylab as plt
import scipy.io
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras import models, layers
from tensorflow import keras
from sklearn.metrics import accuracy_score
from tensorflow.keras.utils import to_categorical
import absl.logging
import tensorflow as tf


def mish(x):
    return x * tf.math.tanh(tf.math.softplus(x))

absl.logging.set_verbosity(absl.logging.ERROR) # .h5 에러메세지 무시

mat_file = scipy.io.loadmat("data/PTSDvsHC.mat")

dataset = mat_file['dataset'] 
# 90개의 데이터, 62개의 전극 채널, 1001의 타임스텝 - 1001씩 이미 에포킹을 한 상태이며, 그에따른 평균을 낸 것임(에포킹에 대해)

subject_test_acc = []

X = dataset
X = X.reshape(90, 1001, 62, 1)
y = mat_file['Y']
y = to_categorical(y, num_classes = 2)

hc_indices = list(range(0, 51))
pg_indices = list(range(51, 90))

fold_val_index_list = []
fold_accuracy = []

input_shape = (1001, 62, 1)

for i in range(len(dataset)): # loso
    test_index = [i]

    hc_val = random.sample([idx for idx in hc_indices if idx not in test_index], 5)
    pg_val = random.sample([idx for idx in pg_indices if idx not in test_index], 5)

    validation_indices = hc_val + pg_val

    training_indices = [idx for idx in range(90) if idx not in test_index + validation_indices]

    fold_val_index_list.append({
        'fold' : i, 
        'test_index' : test_index, 
        'validation_indices' : validation_indices
    })
    
    X_train = X[training_indices, :,  :]
    y_train = y[training_indices, :]
    X_test = X[test_index, :,  :]
    y_test = y[test_index, :]
    X_val = X[validation_indices, :,  :]
    y_val = y[validation_indices, :]

    # print(f"X_train_shape : {X_train.shape}")
    # print(f"X_test_shape : {X_test.shape}")
    # print(f"y_train_shape : {y_train.shape}")
    # print(f"y_test_shape : {y_test.shape}")
    # print(f"X_validation_shape : {X_val.shape}")
    # print(f"y_validation_shape : {y_val.shape}")
    
    model_input = layers.Input(shape = input_shape)
    br1 = layers.Conv2D(32, (50, 1), padding = 'same')(model_input) # temporal filter
    br1 = layers.Activation(mish)(br1) # result1_matrix, shape=(1001, 62, 32)
    # print(br1.shape)

    input_shape_tr = layers.Permute((2, 1, 3))(model_input) # (62, 1001, 1)
    br2 = layers.Conv2D(32, (62, 1), padding = 'same')(input_shape_tr)
    br2 = layers.Activation(mish)(br2) # result2_matrix, shape=(62, 1001, 32)

    # br1, br2 matrix multiply
    br1 = layers.Permute((3, 1, 2))(br1) # (32, 1001, 62)
    br2 = layers.Permute((3, 1, 2))(br2) # (32, 62, 1001)
    br_mul = layers.Lambda(lambda x: tf.matmul(x[0], x[1]))([br2, br1])
    # print(br_mul.shape)  # (32, 62, 62)

    # branch matrix multiply convolution
    br_mul = layers.Permute((2, 3, 1))(br_mul) # (62, 62, 32) <- 풀링하기 위함
    br_mul = layers.Conv2D(16, (3, 3), padding = 'same')(br_mul)
    br_mul = layers.Activation(mish)(br_mul)
    br_mul = layers.GlobalAveragePooling2D()(br_mul)
    end = layers.Flatten()(br_mul)

    prediction = layers.Dense(2, activation = 'softmax')(end)
    model = keras.Model(inputs = model_input, outputs = prediction)
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    history = model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs=100, batch_size=1, verbose=2)
    predictions = model.predict(X_test)
    
    predicted_classes = np.argmax(predictions, axis=1)
    actual_classes = np.argmax(y_test, axis=1)

    acc = accuracy_score(predicted_classes, actual_classes)
    fold_accuracy.append(acc)

    # model.summary()
    
    print(f"fold {i} test accuracy : {acc}\n")

    subject_test_acc.append(acc)
scipy.io.savemat('fold_val_indices.mat', {'fold_val_index_list': fold_val_index_list})
print(f"loso mean accuracy : {np.mean(subject_test_acc)}")
# Out:
# Epoch 1/100
# 79/79 - 4s - 54ms/step - accuracy: 0.5570 - loss: 14.3025 - val_accuracy: 0.5000 - val_loss: 18.5316
# Epoch 2/100
# 79/79 - 3s - 39ms/step - accuracy: 0.4051 - loss: 4.7281 - val_accuracy: 0.6000 - val_loss: 0.5529
# Epoch 3/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6203 - loss: 1.4448 - val_accuracy: 0.5000 - val_loss: 1.1092
# Epoch 4/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6835 - loss: 0.6452 - val_accuracy: 0.5000 - val_loss: 0.8351
# Epoch 5/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6456 - loss: 0.5255 - val_accuracy: 0.6000 - val_loss: 0.7572
# Epoch 6/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7089 - loss: 0.4923 - val_accuracy: 0.7000 - val_loss: 0.7306
# Epoch 7/100
# 79/79 - 3s - 38ms/step - accuracy: 0.7595 - loss: 0.4557 - val_accuracy: 0.5000 - val_loss: 0.6774
# Epoch 8/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7722 - loss: 0.4457 - val_accuracy: 0.6000 - val_loss: 0.6429
# Epoch 9/100
# 79/79 - 3s - 38ms/step - accuracy: 0.8354 - loss: 0.3858 - val_accuracy: 0.6000 - val_loss: 0.9059
# Epoch 10/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7848 - loss: 0.4063 - val_accuracy: 0.6000 - val_loss: 0.5891
# Epoch 11/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8101 - loss: 0.3683 - val_accuracy: 0.9000 - val_loss: 0.4702
# Epoch 12/100
# 79/79 - 3s - 38ms/step - accuracy: 0.8101 - loss: 0.3460 - val_accuracy: 0.9000 - val_loss: 0.4015
# Epoch 13/100
# 79/79 - 3s - 40ms/step - accuracy: 0.8608 - loss: 0.3224 - val_accuracy: 0.7000 - val_loss: 0.5541
# Epoch 14/100
# 79/79 - 3s - 40ms/step - accuracy: 0.7089 - loss: 0.6413 - val_accuracy: 0.7000 - val_loss: 0.6231
# Epoch 15/100
# 79/79 - 3s - 40ms/step - accuracy: 0.6709 - loss: 0.5372 - val_accuracy: 0.5000 - val_loss: 0.7069
# Epoch 16/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7215 - loss: 0.4826 - val_accuracy: 0.6000 - val_loss: 0.6541
# Epoch 17/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6456 - loss: 0.6213 - val_accuracy: 0.5000 - val_loss: 0.6826
# Epoch 18/100
# 79/79 - 3s - 40ms/step - accuracy: 0.6835 - loss: 0.5427 - val_accuracy: 0.5000 - val_loss: 0.6903
# Epoch 19/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6962 - loss: 0.4955 - val_accuracy: 0.4000 - val_loss: 0.7144
# Epoch 20/100
# 79/79 - 3s - 40ms/step - accuracy: 0.7089 - loss: 0.4699 - val_accuracy: 0.6000 - val_loss: 1.1071
# Epoch 21/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6962 - loss: 0.4696 - val_accuracy: 0.5000 - val_loss: 0.7850
# Epoch 22/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7468 - loss: 0.4392 - val_accuracy: 0.6000 - val_loss: 1.0658
# Epoch 23/100
# 79/79 - 3s - 40ms/step - accuracy: 0.6835 - loss: 1.9001 - val_accuracy: 0.5000 - val_loss: 0.7360
# Epoch 24/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5570 - loss: 2.7452 - val_accuracy: 0.6000 - val_loss: 0.6351
# Epoch 25/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5949 - loss: 0.8812 - val_accuracy: 0.5000 - val_loss: 0.6977
# Epoch 26/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.9419 - val_accuracy: 0.5000 - val_loss: 0.7058
# Epoch 27/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.7229 - val_accuracy: 0.5000 - val_loss: 0.7050
# Epoch 28/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6580 - val_accuracy: 0.5000 - val_loss: 0.7038
# Epoch 29/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6520 - val_accuracy: 0.5000 - val_loss: 0.7022
# Epoch 30/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6503 - val_accuracy: 0.5000 - val_loss: 0.7014
# Epoch 31/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6474 - val_accuracy: 0.5000 - val_loss: 0.7011
# Epoch 32/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6456 - val_accuracy: 0.5000 - val_loss: 0.7002
# Epoch 33/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6446 - val_accuracy: 0.5000 - val_loss: 0.7002
# Epoch 34/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6437 - val_accuracy: 0.5000 - val_loss: 0.6983
# Epoch 35/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6428 - val_accuracy: 0.5000 - val_loss: 0.6983
# Epoch 36/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6424 - val_accuracy: 0.5000 - val_loss: 0.6968
# Epoch 37/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6409 - val_accuracy: 0.5000 - val_loss: 0.6982
# Epoch 38/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6401 - val_accuracy: 0.5000 - val_loss: 0.6950
# Epoch 39/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6420 - val_accuracy: 0.5000 - val_loss: 0.6963
# Epoch 40/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6351 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 41/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6317 - val_accuracy: 0.5000 - val_loss: 0.6926
# Epoch 42/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6312 - val_accuracy: 0.5000 - val_loss: 0.6901
# Epoch 43/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6306 - val_accuracy: 0.5000 - val_loss: 0.6904
# Epoch 44/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6311 - val_accuracy: 0.5000 - val_loss: 0.6890
# Epoch 45/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6304 - val_accuracy: 0.5000 - val_loss: 0.6896
# Epoch 46/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6302 - val_accuracy: 0.5000 - val_loss: 0.6887
# Epoch 47/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6298 - val_accuracy: 0.5000 - val_loss: 0.6871
# Epoch 48/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6283 - val_accuracy: 0.5000 - val_loss: 0.6919
# Epoch 49/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6187 - val_accuracy: 0.5000 - val_loss: 0.6914
# Epoch 50/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6138 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 51/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6091 - val_accuracy: 0.5000 - val_loss: 0.6923
# Epoch 52/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6109 - val_accuracy: 0.5000 - val_loss: 0.6906
# Epoch 53/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6071 - val_accuracy: 0.5000 - val_loss: 0.6897
# Epoch 54/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6216 - val_accuracy: 0.5000 - val_loss: 0.6914
# Epoch 55/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6234 - val_accuracy: 0.5000 - val_loss: 0.6886
# Epoch 56/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6218 - val_accuracy: 0.5000 - val_loss: 0.6881
# Epoch 57/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6177 - val_accuracy: 0.5000 - val_loss: 0.6859
# Epoch 58/100
# 79/79 - 3s - 41ms/step - accuracy: 0.5823 - loss: 9.9384 - val_accuracy: 0.5000 - val_loss: 0.6873
# Epoch 59/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6665 - val_accuracy: 0.5000 - val_loss: 0.6834
# Epoch 60/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6076 - loss: 0.6591 - val_accuracy: 0.5000 - val_loss: 0.6872
# Epoch 61/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6482 - val_accuracy: 0.5000 - val_loss: 0.6855
# Epoch 62/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5823 - loss: 0.6454 - val_accuracy: 0.5000 - val_loss: 0.6764
# Epoch 63/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5823 - loss: 0.6465 - val_accuracy: 0.5000 - val_loss: 0.6731
# Epoch 64/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5823 - loss: 0.6402 - val_accuracy: 0.5000 - val_loss: 0.6502
# Epoch 65/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6414 - val_accuracy: 0.5000 - val_loss: 0.6776
# Epoch 66/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6329 - loss: 0.6181 - val_accuracy: 0.8000 - val_loss: 0.4559
# Epoch 67/100
# 79/79 - 3s - 40ms/step - accuracy: 0.6709 - loss: 0.6323 - val_accuracy: 0.9000 - val_loss: 0.5512
# Epoch 68/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6835 - loss: 0.6199 - val_accuracy: 0.9000 - val_loss: 0.5181
# Epoch 69/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7975 - loss: 0.5882 - val_accuracy: 0.9000 - val_loss: 0.4982
# Epoch 70/100
# 79/79 - 3s - 40ms/step - accuracy: 0.7468 - loss: 0.5630 - val_accuracy: 0.7000 - val_loss: 0.6116
# Epoch 71/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8101 - loss: 0.5975 - val_accuracy: 0.9000 - val_loss: 0.4941
# Epoch 72/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7848 - loss: 0.5695 - val_accuracy: 0.9000 - val_loss: 0.5027
# Epoch 73/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8228 - loss: 0.5890 - val_accuracy: 0.9000 - val_loss: 0.4998
# Epoch 74/100
# 79/79 - 3s - 40ms/step - accuracy: 0.7975 - loss: 0.5583 - val_accuracy: 0.9000 - val_loss: 0.4765
# Epoch 75/100
# 79/79 - 5s - 65ms/step - accuracy: 0.8228 - loss: 0.5583 - val_accuracy: 0.9000 - val_loss: 0.4232
# Epoch 76/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7595 - loss: 0.5598 - val_accuracy: 0.9000 - val_loss: 0.4422
# Epoch 77/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7975 - loss: 0.5373 - val_accuracy: 0.9000 - val_loss: 0.4498
# Epoch 78/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8354 - loss: 0.5213 - val_accuracy: 0.8000 - val_loss: 0.3859
# Epoch 79/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7975 - loss: 0.5604 - val_accuracy: 0.9000 - val_loss: 0.4344
# Epoch 80/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8354 - loss: 0.5206 - val_accuracy: 0.7000 - val_loss: 0.5622
# Epoch 81/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7848 - loss: 0.5207 - val_accuracy: 0.9000 - val_loss: 0.4287
# Epoch 82/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7722 - loss: 0.5116 - val_accuracy: 1.0000 - val_loss: 0.4348
# Epoch 83/100
# 79/79 - 3s - 40ms/step - accuracy: 0.7595 - loss: 0.6603 - val_accuracy: 0.9000 - val_loss: 0.4186
# Epoch 84/100
# 79/79 - 3s - 40ms/step - accuracy: 0.6835 - loss: 1.0392 - val_accuracy: 0.6000 - val_loss: 0.6931
# Epoch 85/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5570 - loss: 0.6992 - val_accuracy: 0.5000 - val_loss: 0.7364
# Epoch 86/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6809 - val_accuracy: 0.5000 - val_loss: 0.7312
# Epoch 87/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5949 - loss: 6.0574 - val_accuracy: 0.5000 - val_loss: 0.7283
# Epoch 88/100
# 79/79 - 5s - 65ms/step - accuracy: 0.5570 - loss: 3.2197 - val_accuracy: 0.5000 - val_loss: 0.6576
# Epoch 89/100
# 79/79 - 3s - 38ms/step - accuracy: 0.5570 - loss: 0.7228 - val_accuracy: 0.5000 - val_loss: 0.7239
# Epoch 90/100
# 79/79 - 3s - 38ms/step - accuracy: 0.5696 - loss: 0.6888 - val_accuracy: 0.5000 - val_loss: 0.7175
# Epoch 91/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6725 - val_accuracy: 0.5000 - val_loss: 0.6250
# Epoch 92/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.7435 - val_accuracy: 0.5000 - val_loss: 0.7174
# Epoch 93/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6772 - val_accuracy: 0.5000 - val_loss: 0.7159
# Epoch 94/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6738 - val_accuracy: 0.5000 - val_loss: 0.7139
# Epoch 95/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6731 - val_accuracy: 0.5000 - val_loss: 0.7125
# Epoch 96/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6724 - val_accuracy: 0.5000 - val_loss: 0.7123
# Epoch 97/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6719 - val_accuracy: 0.5000 - val_loss: 0.7104
# Epoch 98/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6715 - val_accuracy: 0.5000 - val_loss: 0.7097
# Epoch 99/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6712 - val_accuracy: 0.5000 - val_loss: 0.7083
# Epoch 100/100
# 79/79 - 3s - 40ms/step - accuracy: 0.5696 - loss: 0.6709 - val_accuracy: 0.5000 - val_loss: 0.7082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# fold 0 test accuracy : 1.0
#
# Epoch 1/100
# 79/79 - 4s - 56ms/step - accuracy: 0.5316 - loss: 19.0765 - val_accuracy: 0.3000 - val_loss: 8.0041
# Epoch 2/100
# 79/79 - 3s - 42ms/step - accuracy: 0.5823 - loss: 4.8491 - val_accuracy: 0.8000 - val_loss: 0.4069
# Epoch 3/100
# 79/79 - 3s - 42ms/step - accuracy: 0.6709 - loss: 0.9087 - val_accuracy: 0.8000 - val_loss: 0.5028
# Epoch 4/100
# 79/79 - 3s - 40ms/step - accuracy: 0.7342 - loss: 0.6566 - val_accuracy: 0.7000 - val_loss: 0.4882
# Epoch 5/100
# 79/79 - 3s - 40ms/step - accuracy: 0.7215 - loss: 0.5227 - val_accuracy: 0.7000 - val_loss: 0.5976
# Epoch 6/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8481 - loss: 0.4044 - val_accuracy: 0.9000 - val_loss: 0.3781
# Epoch 7/100
# 79/79 - 3s - 40ms/step - accuracy: 0.8354 - loss: 0.3803 - val_accuracy: 0.7000 - val_loss: 0.4187
# Epoch 8/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7848 - loss: 0.6483 - val_accuracy: 0.9000 - val_loss: 0.3718
# Epoch 9/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8354 - loss: 0.4943 - val_accuracy: 0.8000 - val_loss: 0.6209
# Epoch 10/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6835 - loss: 1.0001 - val_accuracy: 0.5000 - val_loss: 0.5958
# Epoch 11/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6962 - loss: 0.5230 - val_accuracy: 0.8000 - val_loss: 0.5720
# Epoch 12/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8354 - loss: 0.4048 - val_accuracy: 0.8000 - val_loss: 0.8369
# Epoch 13/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8481 - loss: 0.3525 - val_accuracy: 0.6000 - val_loss: 1.3631
# Epoch 14/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8354 - loss: 0.4097 - val_accuracy: 0.8000 - val_loss: 1.2880
# Epoch 15/100
# 79/79 - 3s - 40ms/step - accuracy: 0.8481 - loss: 0.2946 - val_accuracy: 0.8000 - val_loss: 2.1619
# Epoch 16/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8481 - loss: 0.3322 - val_accuracy: 0.8000 - val_loss: 1.4265
# Epoch 17/100
# 79/79 - 3s - 39ms/step - accuracy: 0.9114 - loss: 0.2381 - val_accuracy: 0.8000 - val_loss: 1.7878
# Epoch 18/100
# 79/79 - 3s - 39ms/step - accuracy: 0.9241 - loss: 0.2139 - val_accuracy: 0.8000 - val_loss: 1.3557
# Epoch 19/100
# 79/79 - 3s - 40ms/step - accuracy: 0.9367 - loss: 0.1782 - val_accuracy: 0.8000 - val_loss: 1.7555
# Epoch 20/100
# 79/79 - 3s - 39ms/step - accuracy: 0.9114 - loss: 0.2535 - val_accuracy: 0.8000 - val_loss: 0.5839
# Epoch 21/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8987 - loss: 0.2173 - val_accuracy: 0.8000 - val_loss: 0.5578
# Epoch 22/100
# 79/79 - 3s - 40ms/step - accuracy: 0.7342 - loss: 0.6389 - val_accuracy: 0.7000 - val_loss: 0.4321
# Epoch 23/100
# 79/79 - 3s - 40ms/step - accuracy: 0.7848 - loss: 0.4347 - val_accuracy: 0.7000 - val_loss: 0.6511
# Epoch 24/100
# 79/79 - 3s - 42ms/step - accuracy: 0.8861 - loss: 0.3320 - val_accuracy: 0.6000 - val_loss: 0.4814
# Epoch 25/100
# 79/79 - 3s - 41ms/step - accuracy: 0.8734 - loss: 0.2393 - val_accuracy: 0.8000 - val_loss: 1.3221
# Epoch 26/100
# 79/79 - 3s - 40ms/step - accuracy: 0.8481 - loss: 0.2969 - val_accuracy: 0.7000 - val_loss: 1.4222
# Epoch 27/100
# 79/79 - 3s - 39ms/step - accuracy: 0.9241 - loss: 0.1676 - val_accuracy: 0.8000 - val_loss: 2.4982
# Epoch 28/100
# 79/79 - 3s - 39ms/step - accuracy: 0.9241 - loss: 0.1801 - val_accuracy: 0.8000 - val_loss: 1.9206
# Epoch 29/100
# 79/79 - 3s - 41ms/step - accuracy: 0.9367 - loss: 0.1655 - val_accuracy: 0.8000 - val_loss: 1.6666
# Epoch 30/100
# 79/79 - 3s - 39ms/step - accuracy: 0.9620 - loss: 0.0790 - val_accuracy: 0.8000 - val_loss: 1.9797
# Epoch 31/100
# 79/79 - 3s - 39ms/step - accuracy: 0.9114 - loss: 0.1944 - val_accuracy: 0.8000 - val_loss: 1.4598
# Epoch 32/100
# 79/79 - 3s - 39ms/step - accuracy: 0.8861 - loss: 0.4198 - val_accuracy: 0.5000 - val_loss: 3.9683
# Epoch 33/100
# 79/79 - 3s - 40ms/step - accuracy: 0.7342 - loss: 0.6932 - val_accuracy: 0.6000 - val_loss: 0.9759
# Epoch 34/100
# 79/79 - 3s - 39ms/step - accuracy: 0.7468 - loss: 0.3799 - val_accuracy: 0.8000 - val_loss: 2.5566
# Epoch 35/100
# 79/79 - 3s - 39ms/step - accuracy: 0.9241 - loss: 0.2365 - val_accuracy: 0.8000 - val_loss: 2.4400
# Epoch 36/100
# 79/79 - 3s - 39ms/step - accuracy: 0.
100
# 79/79 - 3s - 39ms/step - accuracy: 0.5823 - loss: 0.6025 - val_accuracy: 0.4000 - val_loss: 0.7193
# Epoch 97/100
# 79/79 - 3s - 39ms/step - accuracy: 0.6076 - loss: 0.5808 - val_accuracy: 0.5000 - val_loss: 0.9057
# Epoch 98/100
# 79/79 - 3s - 40ms/step - accuracy: 0.6582 - loss: 0.6413 - val_accuracy: 0.5000 - val_loss: 3.8338
# Epoch 99/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6641 - val_accuracy: 0.5000 - val_loss: 0.8491
# Epoch 100/100
# 79/79 - 3s - 39ms/step - accuracy: 0.5696 - loss: 0.6399 - val_accuracy: 0.6000 - val_loss: 1.1287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# fold 1 test accuracy : 1.0
#
# Epoch 1/100
# 79/79 - 4s - 55ms/step - accuracy: 0.5696 - loss: 18.7101 - val_accuracy: 0.6000 - val_loss: 1.1491
# Epoch 2/100
# 79/79 - 3s - 41ms/step - accuracy: 0.6203 - loss: 4.0064 - val_accuracy: 0.6000 - val_loss: 9.8124
# Epoch 3/100
# 79/79 - 3s - 41ms/step - accuracy: 0.6582 - loss: 2.1108 - val_accuracy: 0.5000 - val_loss: 2.2476
# Epoch 4/100
# 79/79 - 3s - 42ms/step - accuracy: 0.8228 - loss: 0.5976 - val_accuracy: 0.5000 - val_loss: 5.4724
# Epoch 5/100
# 79/79 - 3s - 41ms/step - accuracy: 0.7848 - loss: 0.4897 - val_accuracy: 0.5000 - val_loss: 4.0090
# Epoch 6/100
# 79/79 - 3s - 41ms/step - accuracy: 0.8608 - loss: 0.3429 - val_accuracy: 0.6000 - val_loss: 4.2659
# Epoch 7/100
# 79/79 - 4s - 44ms/step - accuracy: 0.8861 - loss: 0.2711 - val_accuracy: 0.6000 - val_loss: 4.4476
# Epoch 8/100
# 79/79 - 3s - 41ms/step - accuracy: 0.8608 - loss: 0.2773 - val_accuracy: 0.6000 - val_loss: 5.0836
# Epoch 9/100
# 79/79 - 3s - 39ms/step - accuracy: 0.9367 - loss: 0.1784 - val_accuracy: 0.7000 - val_loss: 5.1754
# Epoch 10/100
# 79/79 - 3s - 39ms/step - accuracy: 0.9241 - loss: 0.1943 - val_accuracy: 0.6000 - val_loss: 5.7416
# Epoch 11/100
# 79/79 - 3s - 39ms/step - accuracy: 0.9367 - loss: 0.1372 - val_accuracy: 0.6000 - val_loss: 5.8774
# Epoch 12/100
# 79/79 - 3s - 40ms/step - accuracy: 0.8987 - loss: 0.4225 - val_accuracy: 0.4000 - val_loss: 6.2134
# Epoch 13/100
# 79/79 - 3s - 41ms/step - accuracy: 0.7089 - loss: 1.8460 - val_accuracy: 0.7000 - val_loss: 1.6887
# Epoch 14/100
# 79/79 - 3s - 41ms/step - accuracy: 0.6203 - loss: 0.6712 - val_accuracy: 0.6000 - val_loss: 0.6581
# Epoch 15/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 94
#      92 model = keras.Model(inputs = model_input, outputs = prediction)
#      93 model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
# ---> 94 history = model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs=100, batch_size=1, verbose=2)
#      95 predictions = model.predict(X_test)
#      97 predicted_classes = np.argmax(predictions, axis=1)
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:368, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     366 for step, iterator in epoch_iterator:
#     367     callbacks.on_train_batch_begin(step)
# --> 368     logs = self.train_function(iterator)
#     369     callbacks.on_train_batch_end(step, logs)
#     370     if self.stop_training:
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:216, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     212 def function(iterator):
#     213     if isinstance(
#     214         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     215     ):
# --> 216         opt_outputs = multi_step_on_iterator(iterator)
#     217         if not opt_outputs.has_value():
#     218             raise StopIteration
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File ~\miniconda3\envs\sihoon\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
